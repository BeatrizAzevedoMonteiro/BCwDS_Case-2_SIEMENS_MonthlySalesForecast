# %% [markdown]
# <p align="center">
#   <img src="header.jpg" width="100%">
# </p>
#
#
# <div style="text-align: center;">
#     <strong style="display: block; margin-bottom: 10px;">Group P</strong>
#     <table style="margin: 0 auto; border-collapse: collapse; border: 1px solid black;">
#         <tr>
#             <th style="border: 1px solid white; padding: 8px;">Name</th>
#             <th style="border: 1px solid white; padding: 8px;">Student ID</th>
#         </tr>
#         <tr>
#             <td style="border: 1px solid white; padding: 8px;">Beatriz Monteiro</td>
#             <td style="border: 1px solid white; padding: 8px;">20240591</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid white; padding: 8px;">Catarina Nunes</td>
#             <td style="border: 1px solid white; padding: 8px;">20230083</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid white; padding: 8px;">Margarida Raposo</td>
#             <td style="border: 1px solid white; padding: 8px;">20241020</td>
#         </tr>
#         <tr>
#             <td style="border: 1px solid white; padding: 8px;">Teresa Menezes</td>
#             <td style="border: 1px solid white; padding: 8px;">20240333</td>
#         </tr>
#     </table>
# </div>

# %% [markdown]
# ### 🔗 Table of Contents <a id='table-of-contents'></a>
# 1. [Introduction](#introduction)
# 2. [Business Understanding](#business-understanding)
# 3. [Data Understanding](#data-understanding)
# 4. [Data Preparation](#data-preparation)
# 5. [Modeling](#modeling)
# 6. [Evaluation](#evaluation)
# 7. [Conclusion](#conclusion)
#
# ---

# %% [markdown]
# ### <span style="background-color:#235987; padding:5px; border-radius:5px;"> 📌 Introduction <a id='introduction'></a>
#
# This project follows the **CRISP-DM** methodology to conduct a monthly sales forecast of the smart infrastructure business unit of Siemens.
#
#
# #### Montlhy Sales Forecast
#
# <p style="margin-bottom: 50px;"> This case study focuses on ... </p>
#
# **Market Data**
#
# | Features                                      | Feature Description |
# |-----------------------------------------------|---------------------|
# | *date*                                        |  |
# | *China_Production*                            | China - Production Index Machinery & Electricals |
# | *China_Shipment*                              | China - Shipments Index Machinery & Electricals |
# | *France_Production*                           | France - Production Index Machinery & Electricals |
# | *France_Shipment*                             | France - Shipments Index Machinery & Electricals |
# | *Germany_Production*                          | Germany - Production Index Machinery & Electricals |
# | *Germany_Shipment*                            | Germany - Shipments Index Machinery & Electricals |
# | *Italy_Production*                            | Italy - Production Index Machinery & Electricals |
# | *Italy_Shipment*                              | Italy - Shipments Index Machinery & Electricals |
# | *Japan_Production*                            | Japan - Production Index Machinery & Electricals |
# | *Japan_Shipment*                              | Japan - Shipments Index Machinery & Electricals |
# | *Switzerland_Production*                      | Switzerland - Production Index Machinery & Electricals |
# | *Switzerland_Shipment*                        | Switzerland - Shipments Index Machinery & Electricals |
# | *UK_Production*                               | United Kingdom - Production Index Machinery & Electricals |
# | *UK_Shipment*                                 | United Kingdom - Shipments Index Machinery & Electricals |
# | *US_Production*                               | Unied States - Production Index Machinery & Electricals |
# | *US_Shipment*                                 | Unied States - Shipments Index Machinery & Electricals |
# | *Europe_Production*                           | Europe - Production Index Machinery & Electricals |
# | *Europe_Shipment*                             | Europe - Shipments Index Machinery & Electricals |
# | *Base_Metal_Price*                            | World: Price of Base Metals |
# | *Energy_Price*                                | World: Price of Energy |
# | *Metal_and_Minerals_Price*                    | World: Price of Metals  & Minerals |
# | *Natural_Gas_Price*                           | World: Price of Natural gas index |
# | *Crude_oil_avg_Price*                         | World: Price of Crude oil, average |
# | *Copper_price*                                | World: Price of Copper |
# | *LCU_EUR*                                     |  |
# | *US_Producer_Price_Electrical_equip*          |  |
# | *UK_Producer_Price_Electrical_equip*          |  |
# | *Italy_Producer_Price_Electrical_equip*       |  |
# | *France_Producer_Price_Electrical_equip*      |  |
# | *Germany_Producer_Price_Electrical_equip*     |  |
# | *China_Producer_Price_Electrical_equip*       |  |
# | *US_Production_Index_Machinery_and_equipment* |  |
# | *World_Production_Index_Machinery_and_equip*  |  |
# | *Switzerland_Production_Index_Machinery_and_equip* |  |
# | *UK_Production_Index_Machinery_and_equip*     |  |
# | *Italy_Production_Index_Machinery_and_equip*  |  |
# | *Japan_Production_Index_Machinery_and_equip*  |  |
# | *France_Production_Index_Machinery_and_equip* |  |
# | *Germany_Production_Index_Machinery_and_equip* |  |
# | *US_Production_Index_Electrical_equip*        |  |
# | *World_Production_Index_Electrical_equip*     |  |
# | *Switzerland_Production_Index_Electrical_equip* |  |
# | *UK_Production_Index_Electrical_equip*        |  |
# | *Italy_Production_Index_Electrical_equip*     |  |
# | *Japan_Production_Index_Electrical_equip*     |  |
# | *France_Production_Index_Electrical_equip*    |  |
# | *Germany_Production_Index_Electrical_equip*   |  |
#
#
# **Sales Data**
# | Features                                      | Feature Description |
# |-----------------------------------------------|---------------------|
# | *DATE*                                       |   |
# | *Mapped_GCK*                                 |   |
# | *Sales_EUR*                                  |   |
#
# <b style="background-color:#A9A9A9; padding:5px; border-radius:5px; display: inline-block; margin-top: 50px;">CRISP-DM</b>
#
# <ul style="margin-bottom: 30px;">
#     <li><u>Business Understanding</u>: Defining objectives, assessing resources, and project planning.</li>
#     <li><u>Data Understanding</u>: Collecting, exploring, and verifying data quality.</li>
#     <li><u>Data Preparation</u>: Selecting, cleaning, constructing, integrating, and formatting data to ensure it is ready for analysis.</li>
#     <li><u>Modeling</u>: Selecting and applying various modeling techniques while calibrating their parameters to optimal values.</li>
#     <li><u>Evaluation</u>: Select the models which are the best performers and evaluate thoroughly if they align with the business objectives. </li>
#     <li><u>Deployment</u>: Bridge between data mining goals and the business application of the finalized model.</li>
# </ul>
#
# <hr style="margin-top: 30px;">

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
#compose a pallete to use in the vizualizations
pal_novaims = ['#003B5C','#003B5C','#003B5C','#003B5C','#003B5C']
pastel_color = sns.utils.set_hls_values(pal_novaims[1], l=0.4, s=0.3)

# %% [markdown]
# ### <span style="background-color:#235987; padding:5px; border-radius:5px;"> 📌 Business Understanding <a id='business-understanding'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.
# ---

# %% [markdown]
# The **Business Understanding** phase of the project entails the comprehension of the background leading to the project, as well as the business goals and requirements to be achieved.
#
# <b style="background-color:#A9A9A9; padding:5px; border-radius:5px;">Primary Business Objective</b> :
#
#
# <b style="background-color:#A9A9A9; padding:5px; border-radius:5px;">Plan</b> :

# %% [markdown]
# ### <span style="background-color:#235987; padding:5px; border-radius:5px;"> 📌 Data Understanding</span> <a id='data-understanding'></a>
#
# - **[Data Loading and Description](#data-loading-and-description)**
# - **[Data Types](#Data-TypesDU)**
# - **[Univariate EDA: Descriptive Summary](#Descriptive-Summary)**
# - **[Univariate EDA: Missing values](#missing-valuesDU)**
# - **[Inconsistencies](#inconsistenciesDU)**
# - **[Feature Engineering](#feature-engineeringDU)**
# - **[Univariate EDA: Data Visualization](#univariate-vizualization)**
#     - **Numerical Variables:**
#         - [Numeric variables: Histograms](#hist)
#         - [Outliers Analysis: Box-Plots](#box)
#     - **Categorical Variables**
#         - [Categorical variables: Bar Plots](#bar)
#         - [Categorical variables: Geographic Map](#GeographicMap)
# - **[Bivariate EDA: Data Visualization](#Bivariate-Vizualization)**
#    - [Numeric-Numeric: Correlations](#NNCorrelations)
#    - [Numeric-Categorical: Correlations](#NCCorrelations)
#    - [Categorical-Categorical: Cross-tabulations](#CCCross-tabulations)
# - **[Multivariate EDA: Duplicates](#Multivariate)**
#    - [Old Segmentation Vs. All](#old-segmentation)
#    - [Duplicates](#duplicatesdu)
# - **[Market Basket Analysis](#MBA)**
#
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.
# ---

# %% [markdown]
# #### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Data Loading and Description**</span> <a id='data-loading-and-description'></a>
# _This section provides an overview of the dataset, including its structure, size, and general characteristics._
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %% [markdown]
# #### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Market Data**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %%
df_market = pd.read_excel('Data/Case2_Market data.xlsx', sheet_name="Adapted Features", index_col=0)
df_market.head()
# Out:
#         China_Production  China_Shipment  France_Production  France_Shipment  \
# date
# 2004m2         16.940704       16.940704         112.091273        83.458866
# 2004m3         23.711852       23.711852         136.327976       106.168192
# 2004m4         24.435235       24.435235         117.791806        92.007646
# 2004m5         23.708115       23.708115         109.002541        85.696486
# 2004m6         27.009138       27.009138         133.785737       106.641482
#
#         Germany_Production  Germany_Shipment  Italy_Production  \
# date
# 2004m2           82.623037         79.452532        124.289603
# 2004m3          100.556582         97.012918        143.411662
# 2004m4           89.653203         84.932358        129.083828
# 2004m5           86.880571         82.372794        135.590391
# 2004m6           99.010814         95.108740        136.424935
#
#         Italy_Shipment  Japan_Production  Japan_Shipment  \
# date
# ...

# %%
df_market.shape
# Out:
# (219, 47)

# %%
df_market.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries,  2004m2 to  2022m4
# Data columns (total 47 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   China_Production                                  219 non-null    float64
#  1   China_Shipment                                    219 non-null    float64
#  2   France_Production                                 219 non-null    float64
#  3   France_Shipment                                   219 non-null    float64
#  4   Germany_Production                                219 non-null    float64
#  5   Germany_Shipment                                  219 non-null    float64
#  6   Italy_Production                                  219 non-null    float64
#  7   Italy_Shipment                                    219 non-null    float64
# ...

# %%
df_market.describe().T
# Out:
#                                                   count        mean  \
# China_Production                                  219.0  138.303637
# China_Shipment                                    219.0  138.303637
# France_Production                                 219.0  104.431918
# France_Shipment                                   219.0  105.316814
# Germany_Production                                219.0  107.499126
# Germany_Shipment                                  219.0  114.898377
# Italy_Production                                  219.0  105.228363
# Italy_Shipment                                    219.0  105.735378
# Japan_Production                                  219.0  111.948146
# Japan_Shipment                                    219.0  112.670602
# Switzerland_Production                            218.0   97.834543
# Switzerland_Shipment                              218.0   94.784942
# UK_Production                                     219.0  108.752949
# ...

# %%
df_market.columns
# Out:
# Index(['China_Production', 'China_Shipment', 'France_Production',
#        'France_Shipment', 'Germany_Production', 'Germany_Shipment',
#        'Italy_Production', 'Italy_Shipment', 'Japan_Production',
#        'Japan_Shipment', 'Switzerland_Production', 'Switzerland_Shipment',
#        'UK_Production', 'UK_Shipment', 'US_Production', 'US_Shipment',
#        'Europe_Production', 'Europe_Shipment', 'Base_Metal_Price',
#        'Energy_Price', 'Metal_and_Minerals_Price', 'Natural_Gas_Price',
#        'Crude_oil_avg_Price', 'Copper_price', 'LCU_EUR',
#        'US_Producer_Price_Electrical_equip',
#        'UK_Producer_Price_Electrical_equip',
#        'Italy_Producer_Price_Electrical_equip',
#        'France_Producer_Price_Electrical_equip',
#        'Germany_Producer_Price_Electrical_equip',
#        'China_Producer_Price_Electrical_equip',
#        'US_Production_Index_Machinery_and_equip',
#        'World_Production_Index_Machinery_and_equip',
# ...

# %%
df_market.duplicated().sum()
# Out:
# 0

# %%
missing_values = df_market.isnull().sum().to_frame(name='Total')
missing_values['Percentage'] = (missing_values['Total'] / len(df_market) * 100).round(2)
missing_values = missing_values[missing_values['Total'] > 0]
missing_values['Percentage'] = missing_values['Percentage'].astype(str) + '%'
missing_values.sort_values(by='Total', ascending=False, inplace=True)
print(missing_values)
# Out:
#                                                   Total Percentage
# France_Producer_Price_Electrical_equip               35     15.98%
# China_Producer_Price_Electrical_equip                23      10.5%
# UK_Shipment                                          18      8.22%
# UK_Producer_Price_Electrical_equip                   18      8.22%
# World_Production_Index_Electrical_equip              11      5.02%
# Switzerland_Production                                1      0.46%
# Switzerland_Shipment                                  1      0.46%
# US_Shipment                                           1      0.46%
# Switzerland_Production_Index_Machinery_and_equip      1      0.46%
# Switzerland_Production_Index_Electrical_equip         1      0.46%

# %%
# Check for negative values in numeric columns where negatives don't make sense
negative_values = df_market[
    (df_market['Base_Metal_Price'] < 0) |
    (df_market['Energy_Price'] < 0) |
    (df_market['Metal_and_Minerals_Price'] < 0) |
    (df_market['Natural_Gas_Price'] < 0) |
    (df_market['Crude_oil_avg_Price'] < 0) |
    (df_market['Copper_price'] < 0) 
]
print(f"Negative Values Found: {negative_values.shape[0]} records")
# Out:
# Negative Values Found: 0 records

# %%
# Check for any negative values in the entire dataset
positive_values = (df_market > 0).any().any()

if positive_values:
    print("Positive values exist in the dataset.")
else:
    print("No positive values found in the dataset.")
# Out:
# Positive values exist in the dataset.

# %% [markdown]
# ##### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Correct Market Data Types**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %%
# change the index format
df_market.index = pd.to_datetime(df_market.index.astype(str).str.replace('m', '-').str.strip(), format='%Y-%m')

# %% [markdown]
# ##### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Data Visualization Market Data**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %%
production_shipment_columns = [
    'China_Production', 'China_Shipment', 'France_Production', 'France_Shipment',
    'Germany_Production', 'Germany_Shipment', 'Italy_Production', 'Italy_Shipment',
    'Japan_Production', 'Japan_Shipment', 'Switzerland_Production', 'Switzerland_Shipment',
    'UK_Production', 'UK_Shipment', 'US_Production', 'US_Shipment',
    'Europe_Production', 'Europe_Shipment'
]

# compute correlation matrix
corr_matrix = df_market[production_shipment_columns].corr()

plt.figure(figsize=(16, 10))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Production and Shipment by Country")
plt.show()

# %% [markdown]
# #### Analysis of the Correlation Matrix:
# - 'China Production' and 'China Shipment' with 1 of correlation.
# - 'Germany Production' and 'Germany Shipment' with a strong correlation (0.9) which might indicate a highly optimized, demand-driven production system.

# %%
shipment_columns = [
    'China_Shipment', 'France_Shipment',
    'Germany_Shipment', 'Italy_Shipment',
    'Japan_Shipment', 'Switzerland_Shipment',
    'UK_Shipment', 'US_Shipment','Europe_Shipment'
]

# compute correlation matrix
corr_matrix = df_market[shipment_columns].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Shipment by Country")
plt.show()

# %%
production_columns = [
    'China_Production', 'France_Production', 
    'Germany_Production', 'Italy_Production',
    'Japan_Production', 'Switzerland_Production', 
    'UK_Production', 'US_Production',
    'Europe_Production'
]

# compute correlation matrix
corr_matrix = df_market[production_columns].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Production by Country")
plt.show()

# %%
metal_price_columns = ['Base_Metal_Price',
       'Energy_Price', 'Metal_and_Minerals_Price', 'Natural_Gas_Price',
       'Crude_oil_avg_Price', 'Copper_price', 'LCU_EUR']

# compute correlation matrix
corr_matrix = df_market[metal_price_columns].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Matrix of Production and Shipment by Country")
plt.show()

# %% [markdown]
# #### Comparing Shipment and Production

# %%
shipment_columns = [
    'China_Shipment', 'France_Shipment',
    'Germany_Shipment', 'Italy_Shipment',
    'Japan_Shipment', 'Switzerland_Shipment',
    'UK_Shipment', 'US_Shipment','Europe_Shipment'
]

production_columns = [
    'China_Production', 'France_Production', 
    'Germany_Production', 'Italy_Production',
    'Japan_Production', 'Switzerland_Production', 
    'UK_Production', 'US_Production',
    'Europe_Production'
]

# %%
# calculate the sum of each shipment per country column
total_china_shipment = df_market['China_Shipment'].sum()
total_france_shipment = df_market['France_Shipment'].sum()
total_germany_shipment = df_market['Germany_Shipment'].sum()
total_italy_shipment = df_market['Italy_Shipment'].sum()
total_japan_shipment = df_market['Japan_Shipment'].sum()
total_swiss_shipment = df_market['Switzerland_Shipment'].sum()
total_uk_shipment = df_market['UK_Shipment'].sum()
total_us_shipment = df_market['US_Shipment'].sum()
total_europe_shipment = df_market['Europe_Shipment'].sum()

total_shipment_countries=['total_china_shipment', 'total_france_shipment', 'total_germany_shipment',
                          'total_italy_shipment', 'total_japan_shipment', 'total_swiss_shipment',
                          'total_uk_shipment', 'total_us_shipment', 'total_europe_shipment']

# %%
countries = ['China', 'France', 'Germany', 'Italy', 'Japan', 'Switzerland', 'UK', 'US', 'Europe']

# Plot histogram
plt.figure(figsize=(10, 6))
plt.bar(countries, total_shipment_countries, color='skyblue')

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Total Shipment')
plt.title('Total Shipments per Country')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# calculate the sum of each production per country column
total_china_production = df_market['China_Production'].sum()
total_france_production = df_market['France_Production'].sum()
total_germany_production = df_market['Germany_Production'].sum()
total_italy_production = df_market['Italy_Production'].sum()
total_japan_production = df_market['Japan_Production'].sum()
total_swiss_production = df_market['Switzerland_Production'].sum()
total_uk_production = df_market['UK_Production'].sum()
total_us_production = df_market['US_Production'].sum()
total_europe_production = df_market['Europe_Production'].sum()

total_production_countries=['total_china_production', 'total_france_production', 'total_germany_production',
                             'total_italy_production','total_japan_production','total_swiss_production', 
                             'total_uk_production', 'total_us_production', 'total_europe_production']

# %%
countries = ['China', 'France', 'Germany', 'Italy', 'Japan', 'Switzerland', 'UK', 'US', 'Europe']

# Plot histogram for production
plt.figure(figsize=(10, 6))
plt.bar(countries, total_production_countries, color='royalblue')

# Adding labels and title
plt.xlabel('Country')
plt.ylabel('Total Production')
plt.title('Total Production per Country')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data (as per your structure)
dates = pd.date_range(start='2023-01-01', periods=12, freq='M')
data = {
    'Date': dates,
    'China_Production': np.random.randint(90, 110, size=12), 'China_Shipment': np.random.randint(85, 105, size=12),
    'France_Production': np.random.randint(70, 90, size=12), 'France_Shipment': np.random.randint(65, 85, size=12),
    'Germany_Production': np.random.randint(110, 130, size=12), 'Germany_Shipment': np.random.randint(105, 125, size=12),
    'Italy_Production': np.random.randint(80, 100, size=12), 'Italy_Shipment': np.random.randint(75, 95, size=12),
    'Japan_Production': np.random.randint(100, 120, size=12), 'Japan_Shipment': np.random.randint(95, 115, size=12),
    'Switzerland_Production': np.random.randint(60, 80, size=12), 'Switzerland_Shipment': np.random.randint(55, 75, size=12),
    'UK_Production': np.random.randint(75, 95, size=12), 'UK_Shipment': np.random.randint(70, 90, size=12),
    'US_Production': np.random.randint(85, 105, size=12), 'US_Shipment': np.random.randint(80, 100, size=12),
    'Europe_Production': np.random.randint(120, 140, size=12), 'Europe_Shipment': np.random.randint(115, 135, size=12)
}
df = pd.DataFrame(data)

# Plot Production vs Shipment for each country individually
countries = ['China', 'France', 'Germany', 'Italy', 'Japan', 'Switzerland', 'UK', 'US', 'Europe']

fig, axes = plt.subplots(3, 3, figsize=(15, 12))  # Adjust the size to fit all plots
axes = axes.flatten()  # Flatten the 2D array of axes to 1D for easier indexing

for i, country in enumerate(countries):
    ax = axes[i]
    ax.plot(df['Date'], df[f'{country}_Production'], label=f'{country} Production', linestyle='dashed', color='blue')
    ax.plot(df['Date'], df[f'{country}_Shipment'], label=f'{country} Shipment', linestyle='solid', color='orange')
    ax.set_title(f'{country} Production vs Shipment')
    ax.set_xlabel('Date')
    ax.set_ylabel('Values')
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
    ax.grid()

plt.tight_layout()
plt.xticks(rotation=45)
plt.show()
# Out:
# /var/folders/4x/qxl9m2614f9bccbgjvlpk9kw0000gn/T/ipykernel_50420/391525608.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2023-01-01', periods=12, freq='M')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Create a Date range from 2004 to 2022 with monthly frequency
dates = pd.date_range(start='2004-01-01', end='2022-12-31', freq='M')

# We will take a sample of 12 months of data from this range
sample_dates = np.random.choice(dates, size=12, replace=False)
sample_dates.sort()

# Sample data (adjusted for 12 random months from the range)
data = {
    'Date': sample_dates,
    'China_Production': np.random.randint(90, 110, size=12), 'China_Shipment': np.random.randint(85, 105, size=12),
    'France_Production': np.random.randint(70, 90, size=12), 'France_Shipment': np.random.randint(65, 85, size=12),
    'Germany_Production': np.random.randint(110, 130, size=12), 'Germany_Shipment': np.random.randint(105, 125, size=12),
    'Italy_Production': np.random.randint(80, 100, size=12), 'Italy_Shipment': np.random.randint(75, 95, size=12),
    'Japan_Production': np.random.randint(100, 120, size=12), 'Japan_Shipment': np.random.randint(95, 115, size=12),
    'Switzerland_Production': np.random.randint(60, 80, size=12), 'Switzerland_Shipment': np.random.randint(55, 75, size=12),
    'UK_Production': np.random.randint(75, 95, size=12), 'UK_Shipment': np.random.randint(70, 90, size=12),
    'US_Production': np.random.randint(85, 105, size=12), 'US_Shipment': np.random.randint(80, 100, size=12),
    'Europe_Production': np.random.randint(120, 140, size=12), 'Europe_Shipment': np.random.randint(115, 135, size=12)
}
df_market = pd.DataFrame(data)

# List of countries to plot
countries = ['China', 'France', 'Germany', 'Italy', 'Japan', 'Switzerland', 'UK', 'US', 'Europe']

# Create a figure with 9 rows and 1 column (1 graph per row)
fig, axes = plt.subplots(len(countries), 1, figsize=(10, 4 * len(countries)))  # Adjust figure size

for i, country in enumerate(countries):
    ax = axes[i]
    ax.plot(df_market['Date'], df_market[f'{country}_Production'], label=f'{country} Production', linestyle='dashed', color='blue')
    ax.plot(df_market['Date'], df_market[f'{country}_Shipment'], label=f'{country} Shipment', linestyle='solid', color='orange')
    ax.set_title(f'{country} Production vs Shipment')
    ax.set_xlabel('Date')
    ax.set_ylabel('Values')
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
    ax.grid()

plt.tight_layout()  # Adjusts layout to prevent overlap
plt.xticks(rotation=45)  # Rotate date labels
plt.show()
# Out:
# /var/folders/4x/qxl9m2614f9bccbgjvlpk9kw0000gn/T/ipykernel_50420/2430367689.py:6: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2004-01-01', end='2022-12-31', freq='M')

# %%
 # Add your actual values here
shipment_columns = [
    'China_Shipment', 'France_Shipment',
    'Germany_Shipment', 'Italy_Shipment',
    'Japan_Shipment', 'Switzerland_Shipment',
    'UK_Shipment', 'US_Shipment','Europe_Shipment'
]

production_columns = [
    'China_Production', 'France_Production', 
    'Germany_Production', 'Italy_Production',
    'Japan_Production', 'Switzerland_Production', 
    'UK_Production', 'US_Production',
    'Europe_Production'
]

# calculate the sum of each shipment per country column
total_china_shipment = df_market['China_Shipment'].sum()
total_france_shipment = df_market['France_Shipment'].sum()
total_germany_shipment = df_market['Germany_Shipment'].sum()
total_italy_shipment = df_market['Italy_Shipment'].sum()
total_japan_shipment = df_market['Japan_Shipment'].sum()
total_swiss_shipment = df_market['Switzerland_Shipment'].sum()
total_uk_shipment = df_market['UK_Shipment'].sum()
total_us_shipment = df_market['US_Shipment'].sum()
total_europe_shipment = df_market['Europe_Shipment'].sum()

total_shipment_countries=['total_china_shipment', 'total_france_shipment', 'total_germany_shipment',
                          'total_italy_shipment', 'total_japan_shipment', 'total_swiss_shipment',
                          'total_uk_shipment', 'total_us_shipment', 'total_europe_shipment']

# calculate the sum of each production per country column
total_china_production = df_market['China_Production'].sum()
total_france_production = df_market['France_Production'].sum()
total_germany_production = df_market['Germany_Production'].sum()
total_italy_production = df_market['Italy_Production'].sum()
total_japan_production = df_market['Japan_Production'].sum()
total_swiss_production = df_market['Switzerland_Production'].sum()
total_uk_production = df_market['UK_Production'].sum()
total_us_production = df_market['US_Production'].sum()
total_europe_production = df_market['Europe_Production'].sum()

total_production_countries=['total_china_production', 'total_france_production', 'total_germany_production',
                             'total_italy_production','total_japan_production','total_swiss_production', 
                             'total_uk_production', 'total_us_production', 'total_europe_production']

# %%
dates = pd.date_range(start='2023-01-01', periods=12, freq='M')
data = {
    'Date': dates,
    'China_Production': np.random.randint(90, 110, size=12), 'China_Shipment': np.random.randint(85, 105, size=12),
    'France_Production': np.random.randint(70, 90, size=12), 'France_Shipment': np.random.randint(65, 85, size=12),
    'Germany_Production': np.random.randint(110, 130, size=12), 'Germany_Shipment': np.random.randint(105, 125, size=12),
    'Italy_Production': np.random.randint(80, 100, size=12), 'Italy_Shipment': np.random.randint(75, 95, size=12),
    'Japan_Production': np.random.randint(100, 120, size=12), 'Japan_Shipment': np.random.randint(95, 115, size=12),
    'Switzerland_Production': np.random.randint(60, 80, size=12), 'Switzerland_Shipment': np.random.randint(55, 75, size=12),
    'UK_Production': np.random.randint(75, 95, size=12), 'UK_Shipment': np.random.randint(70, 90, size=12),
    'US_Production': np.random.randint(85, 105, size=12), 'US_Shipment': np.random.randint(80, 100, size=12),
    'Europe_Production': np.random.randint(120, 140, size=12), 'Europe_Shipment': np.random.randint(115, 135, size=12)
}
df = pd.DataFrame(data)

# Plot Production vs Shipment over time
plt.figure(figsize=(12, 6))
for country in ['China', 'France', 'Germany', 'Italy', 'Japan', 'Switzerland', 'UK', 'US', 'Europe']:
    plt.plot(df['Date'], df[f'{country}_Production'], label=f'{country} Production', linestyle='dashed')
    plt.plot(df['Date'], df[f'{country}_Shipment'], label=f'{country} Shipment', linestyle='solid')

plt.xlabel("Date")
plt.ylabel("Values")
plt.title("Production vs Shipment Over Time")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.xticks(rotation=45)
plt.grid()
plt.show()
# Out:
# /var/folders/4x/qxl9m2614f9bccbgjvlpk9kw0000gn/T/ipykernel_50420/2793728.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   dates = pd.date_range(start='2023-01-01', periods=12, freq='M')

# %%
# Sample data for Production and Shipment values
countries = ["China", "France", "Germany", "Italy", "Japan", "Switzerland", "UK", "US", "Europe"]

# Bar chart setup
x = np.arange(len(countries))
width = 0.4  # Width of the bars

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(x - width/2, production_columns, width, label='Production', color='blue', alpha=0.7)
ax.bar(x + width/2, shipment_columns, width, label='Shipment', color='orange', alpha=0.7)

# Labels and title
ax.set_xlabel("Country")
ax.set_ylabel("Values")
ax.set_title("Production vs Shipment by Country")
ax.set_xticks(x)
ax.set_xticklabels(countries, rotation=45)
ax.legend()

# Show the plot
plt.show()

# %%
label_mapping = {
    'MAB_ELE_PRO156': 'China',
    'MAB_ELE_PRO250': 'France',
    'MAB_ELE_PRO276': 'Germany',
    'MAB_ELE_PRO380': 'Italy',
    'MAB_ELE_PRO392': 'Japan',
    'MAB_ELE_PRO756': 'Switzerland',
    'MAB_ELE_PRO826': 'United Kingdom',
    'MAB_ELE_PRO840': 'United States',
    'MAB_ELE_PRO1100': 'Europe'
}
column_pairs = [('MAB_ELE_PRO156', 'MAB_ELE_SHP156'),
                ('MAB_ELE_PRO250', 'MAB_ELE_SHP250'),
                ('MAB_ELE_PRO276', 'MAB_ELE_SHP276'),
                ('MAB_ELE_PRO380', 'MAB_ELE_SHP380'),
                ('MAB_ELE_PRO392', 'MAB_ELE_SHP392'),
                ('MAB_ELE_PRO756', 'MAB_ELE_SHP756'),
                ('MAB_ELE_PRO826', 'MAB_ELE_SHP826'),
                ('MAB_ELE_PRO840', 'MAB_ELE_SHP840'),
                ('MAB_ELE_PRO1100',	'MAB_ELE_SHP1100')]

# Plot each pair of columns in smaller figures
for i, pair in enumerate(column_pairs, start=1):
    plt.figure(figsize=(6, 4))  # Set smaller figure size
    plt.plot(df_market.index, df_market[pair[0]], label='Production')
    plt.plot(df_market.index, df_market[pair[1]], label='Shipment')
    plt.axhline(y=100, color='red', linestyle='--')  # Add dashed line at y=100
    plt.xlabel('Time')
    plt.ylabel('Index')
    plt.title(f'{label_mapping[pair[0]]} - Production vs Shipment index')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MAB_ELE_PRO156'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 25
#      23 for i, pair in enumerate(column_pairs, start=1):
# ...

# %% [markdown]
# #### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Sales Data**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %%
df_sales = pd.read_csv('Data/Case2_Sales data.csv', delimiter=';')
df_sales.head()
# Out:
#          DATE Mapped_GCK Sales_EUR
# 0  01.10.2018         #1         0
# 1  02.10.2018         #1         0
# 2  03.10.2018         #1         0
# 3  04.10.2018         #1         0
# 4  05.10.2018         #1         0

# %%
df_sales.describe()
# Out:
#               DATE Mapped_GCK Sales_EUR
# count         9802       9802      9802
# unique        1216         14      2609
# top     16.04.2021         #1         0
# freq            14       1179      7134

# %%
df_sales.shape
# Out:
# (9802, 3)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9802 entries, 0 to 9801
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DATE        9802 non-null   object
#  1   Mapped_GCK  9802 non-null   object
#  2   Sales_EUR   9802 non-null   object
# dtypes: object(3)
# memory usage: 229.9+ KB

# %%
missing_values_sales = df_sales.isnull().sum()

features_with_missing_values_sales = missing_values_sales[missing_values_sales > 0]
features_with_missing_values_sales
# Out:
# Series([], dtype: int64)

# %%
num_unique_dates = df_sales['DATE'].nunique()
print(num_unique_dates)
# Out:
# 1216

# %%
df_sales.duplicated().sum()
# Out:
# 0

# %%
missing_values_sales = df_sales.isnull().sum().to_frame(name='Total')
missing_values_sales['Percentage'] = (missing_values_sales['Total'] / len(df_sales) * 100).round(2)
missing_values_sales = missing_values_sales[missing_values_sales['Total'] > 0]
missing_values_sales['Percentage'] = missing_values_sales['Percentage'].astype(str) + '%'
missing_values_sales.sort_values(by='Total', ascending=False, inplace=True)
print(missing_values_sales)
# Out:
# Empty DataFrame
# Columns: [Total, Percentage]
# Index: []

# %% [markdown]
# - There are no missing values in 'df_sales'.

# %%
# remove the # symbol
df_sales['Mapped_GCK'] = df_sales['Mapped_GCK'].astype(str).str.replace('#', '', regex=False)
# unique value of Mapped_GCK
df_sales['Mapped_GCK'].value_counts()
# Out:
# Mapped_GCK
# 1     1179
# 3     1017
# 5      959
# 8      944
# 4      877
# 12     803
# 6      794
# 16     765
# 11     732
# 13     441
# 36     434
# 9      333
# 20     293
# 14     231
# Name: count, dtype: int64

# %% [markdown]
# ##### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Correct Sales Data Types**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %%
df_sales['DATE'] = pd.to_datetime(df_sales['DATE'], format='%d.%m.%Y')
# replace commas with dots
df_sales['Sales_EUR'] = df_sales['Sales_EUR'].astype(str).str.replace(',', '.', regex=False).astype(float)

# %%
df_sales.head()
# Out:
#         DATE Mapped_GCK  Sales_EUR
# 0 2018-10-01          1        0.0
# 1 2018-10-02          1        0.0
# 2 2018-10-03          1        0.0
# 3 2018-10-04          1        0.0
# 4 2018-10-05          1        0.0

# %%
# check for negative values in numeric columns
negative_values = df_sales[
    (df_sales['Sales_EUR'] < 0)
]
print(f"Negative Values Found: {negative_values.shape[0]} records")
# Out:
# Negative Values Found: 276 records

# %%
negative_values
# Out:
#            DATE Mapped_GCK  Sales_EUR
# 90   2022-02-02          6     -54.00
# 96   2022-04-04         11    -587.59
# 102  2021-12-02          3    -183.50
# 130  2022-03-02          6     -93.88
# 155  2021-05-03          5    -166.24
# ...         ...        ...        ...
# 9333 2019-09-03         20      -6.60
# 9466 2018-11-05          4   -2029.91
# 9487 2019-04-30         13     -26.31
# 9681 2020-07-31          9     -35.25
# 9775 2019-03-26          8   -1000.00
#
# [276 rows x 3 columns]

# %%
negative_values['Mapped_GCK'].value_counts()
# Out:
# Mapped_GCK
# 3     56
# 1     51
# 5     43
# 4     40
# 8     19
# 9     11
# 6     10
# 12    10
# 36     8
# 11     7
# 14     7
# 16     6
# 20     5
# 13     3
# Name: count, dtype: int64

# %%
# extract the year from 'DATE'
negative_by_year = negative_values.groupby(negative_values['DATE'].dt.year)['Mapped_GCK'].count()
print(negative_by_year)
# Out:
# DATE
# 2018    11
# 2019    88
# 2020    72
# 2021    73
# 2022    32
# Name: Mapped_GCK, dtype: int64

# %%
# extract the year and month from 'DATE'
negative_values['YearMonth'] = negative_values['DATE'].dt.to_period('M')
# group them and count the negative values in 'Mapped_GCK'
negative_by_month = negative_values.groupby('YearMonth')['Mapped_GCK'].count().reset_index()
print(negative_by_month)
# Out:
#    YearMonth  Mapped_GCK
# 0    2018-11           6
# 1    2018-12           5
# 2    2019-01           5
# 3    2019-02           4
# 4    2019-03          11
# 5    2019-04          10
# 6    2019-05           6
# 7    2019-06           4
# 8    2019-07           3
# 9    2019-08           8
# 10   2019-09          10
# 11   2019-10          11
# 12   2019-11           4
# 13   2019-12          12
# 14   2020-01           9
# 15   2020-02           7
# 16   2020-03           6
# 17   2020-04           8
# 18   2020-05           5
# 19   2020-06           7
# 20   2020-07           6
# 21   2020-08           3
# 22   2020-09           1
# 23   2020-10           7
# 24   2020-11           8
# 25   2020-12           5
# 26   2021-01           2
# 27   2021-02           4
# 28   2021-03           7
# 29   2021-04           5
# 30   2021-05           7
# 31   2021-06           4
# 32   2021-07           6
# 33   2021-08           4
# 34   2021-09          10
# 35   2021-10           7
# ...

# %% [markdown]
# #### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Sales Data Visualization**</span> <a id='data-loading-and-description'></a>
#
# ##### Click [here](#table-of-contents) ⬆️ to return to the Index.

# %% [markdown]
# ##### <span style="background-color:#235987; padding:5px; border-radius:5px;">**Negative Sales**</span> <a id='data-loading-and-description'></a>

# %%
x_labels = negative_by_month['YearMonth']
x_ticks = np.arange(0, len(x_labels), 6)  # every 6th month

# plotting the results
plt.figure(figsize=(12, 4))
plt.plot(x_labels, negative_by_month['Mapped_GCK'], marker='o', color='cornflowerblue', linestyle='-', linewidth=2)

# formatting the plot
plt.title('Negative Mapped_GCK Counts by Month')
plt.xlabel('Year-Month')
plt.ylabel('Negative Mapped_GCK Count')
plt.xticks(ticks=x_ticks, labels=x_labels[x_ticks], rotation=0)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
negative_values['DATE'] = pd.to_datetime(negative_values['DATE'])

# extract the year from 'DATE'
negative_values['Year'] = negative_values['DATE'].dt.year

# group by 'Year' and count the occurrences of negative values in 'Mapped_GCK'
negative_by_year = negative_values.groupby('Year')['Mapped_GCK'].count().reset_index()

# plotting the results
plt.figure(figsize=(8, 4))
plt.bar(negative_by_year['Year'].astype(str), negative_by_year['Mapped_GCK'], color='cornflowerblue')
plt.title('Negative Mapped_GCK Counts by Year')
plt.xlabel('Year')
plt.ylabel('Negative Mapped_GCK Count')
plt.xticks(rotation=0) 
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ##### <span style="background-color:#235987; padding:5px; border-radius:5px;">**All Sales**</span> <a id='data-loading-and-description'></a>

# %%
# group the data by 'YearMonth' and sum the total sales
df_sales['YearMonth'] = df_sales['DATE'].dt.to_period('M')
sales_by_month = df_sales.groupby('YearMonth')['Sales_EUR'].sum().reset_index()
# convert 'YearMonth' to string for x-axis labels
sales_by_month['YearMonth'] = sales_by_month['YearMonth'].astype(str)
x_labels = sales_by_month['YearMonth']
x_ticks = np.arange(0, len(x_labels), 6)  # every 6th month

# plotting the results
plt.figure(figsize=(12, 4))
plt.plot(x_labels, sales_by_month['Sales_EUR'], marker='o', color='cornflowerblue', linestyle='-', linewidth=2)
plt.title('Total Sales (EUR) by Month')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales (EUR)')
plt.xticks(ticks=x_ticks, labels=x_labels[x_ticks], rotation=0)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# extract the year from 'DATE'
df_sales['Year'] = df_sales['DATE'].dt.year

# group by 'Year' and sum the 'Sales_EUR'
sales_by_year = df_sales.groupby('Year')['Sales_EUR'].sum().reset_index()

# plotting the results
plt.figure(figsize=(8, 4))
plt.bar(sales_by_year['Year'].astype(str), sales_by_year['Sales_EUR'], color='cornflowerblue')
plt.title('Total Sales (EUR) by Year')
plt.xlabel('Year')
plt.ylabel('Total Sales (EUR)')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# histogram dos mapped
